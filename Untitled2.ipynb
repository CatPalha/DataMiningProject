# %% [markdown]
# ## Data Mining Report

# %%
import pandas as pd

# %%
df = pd.read_csv('A2Z_insurance.csv')

# %%
df.head()
df.shape
# Out:
# (10296, 17)

# %% [markdown]
# Problems:
#
# - People too young or too old
# - Birthday dates and first year of insurance dates
# - Sum(Preminums) greater than Salary

# %%
#Age Columns
df['Age'] = 2016 - df['Brithday Year']
df['Age As Client'] = 2016 - df['First Policy´s Year']
df.columns
# Out:
# Index(['Customer Identity', 'First Policy´s Year', 'Brithday Year',
#        'Educational Degree', 'Gross Monthly Salary', 'Geographic Living Area',
#        'Has Children (Y=1)', 'Customer Monetary Value', 'Claims Rate',
#        'Premiums in LOB: Motor', 'Premiums in LOB: Household',
#        'Premiums in LOB: Health', 'Premiums in LOB:  Life',
#        'Premiums in LOB: Work Compensations', 'Age', 'Age As Client'],
#       dtype='object')

# %%
df[df['First Policy´s Year'] < df['Brithday Year']].count()
# Out:
# Customer Identity                      1997
# First Policy´s Year                    1997
# Brithday Year                          1997
# Educational Degree                     1996
# Gross Monthly Salary                   1985
# Geographic Living Area                 1997
# Has Children (Y=1)                     1994
# Customer Monetary Value                1997
# Claims Rate                            1997
# Premiums in LOB: Motor                 1989
# Premiums in LOB: Household             1997
# Premiums in LOB: Health                1985
# Premiums in LOB:  Life                 1985
# Premiums in LOB: Work Compensations    1981
# Age                                    1997
# Age As Client                          1997
# dtype: int64

# %%
#The have a guy from the future and one guy with 965y
#We'll delete these rows by index.
print(df[df['Brithday Year'] == 1028.0].index) #Index 7197
print(df[df['First Policy´s Year'] == 53784].index) #Index 9294
# Out:
# Int64Index([7195], dtype='int64')
# Int64Index([9294], dtype='int64')

# %%
df['premiums_sum'] = df['Premiums in LOB: Motor'] +  df['Premiums in LOB: Household'] + df['Premiums in LOB: Health'] + df['Premiums in LOB:  Life'] + df['Premiums in LOB: Work Compensations']

# %%
df[df['premiums_sum'] > df['Gross Monthly Salary']]
#581 costumers
# Out:
#        Customer Identity  First Policy´s Year  Brithday Year  \
# 1                      2               1981.0         1995.0
# 108                  109               1991.0         1995.0
# 182                  183               1995.0         1991.0
# 186                  187               1993.0         1999.0
# 241                  242               1983.0         1986.0
# 245                  246               1984.0         1993.0
# 257                  258               1991.0         1995.0
# 265                  266               1997.0         1990.0
# 343                  344               1976.0         1978.0
# 394                  395               1989.0         1992.0
# 397                  398               1986.0         2000.0
# 432                  433               1996.0         1995.0
# 462                  463               1992.0         1997.0
# 463                  464               1994.0         1994.0
# ...
