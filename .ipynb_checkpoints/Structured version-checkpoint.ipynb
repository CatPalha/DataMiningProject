# %% [markdown]
# # first look

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('A2Z_insurance.csv')

# %%
def FirstLook(df):
    
    """Given a dataFrame the function prints the best insights."""
    
    print("First 5 rows of the dataFrame: \n\n", df.head())
    print("Shape: \n\n", df.shape)
    print("Columns names: \n\n", df.columns)
    print("Columns types: \n\n", df.dtypes)
    print("Description: \n\n", df.describe())

# %%
FirstLook(df)
# Out:
# First 5 rows of the dataFrame:
#
#     Customer Identity  First Policy´s Year  Brithday Year Educational Degree  \
# 0                  1               1985.0         1982.0    2 - High School
# 1                  2               1981.0         1995.0    2 - High School
# 2                  3               1991.0         1970.0          1 - Basic
# 3                  4               1990.0         1981.0        3 - BSc/MSc
# 4                  5               1986.0         1973.0        3 - BSc/MSc
#
#    Gross Monthly Salary  Geographic Living Area  Has Children (Y=1)  \
# 0                2177.0                     1.0                 1.0
# 1                 677.0                     4.0                 1.0
# 2                2277.0                     3.0                 0.0
# 3                1099.0                     4.0                 1.0
# 4                1763.0                     4.0                 1.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Customer Identity                        0
# First Policy´s Year                     30
# Brithday Year                           17
# Educational Degree                      17
# Gross Monthly Salary                    36
# Geographic Living Area                   1
# Has Children (Y=1)                      21
# Customer Monetary Value                  0
# Claims Rate                              0
# Premiums in LOB: Motor                  34
# Premiums in LOB: Household               0
# Premiums in LOB: Health                 43
# Premiums in LOB:  Life                 104
# Premiums in LOB: Work Compensations     86
# dtype: int64

# %%
df.shape
# Out:
# (10296, 14)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # data cleaning

# %% [markdown]
# ## replacing nulls

# %%
# delete all nulls

df = df.dropna()

# %%
df.shape
# Out:
# (9987, 14)

# %%
df.isnull().sum()
# Out:
# Customer Identity                      0
# First Policy´s Year                    0
# Brithday Year                          0
# Educational Degree                     0
# Gross Monthly Salary                   0
# Geographic Living Area                 0
# Has Children (Y=1)                     0
# Customer Monetary Value                0
# Claims Rate                            0
# Premiums in LOB: Motor                 0
# Premiums in LOB: Household             0
# Premiums in LOB: Health                0
# Premiums in LOB:  Life                 0
# Premiums in LOB: Work Compensations    0
# dtype: int64

# %% [markdown]
# ## renaming columns

# %%
df = df.rename(columns={'Customer Identity':'ID','First Policy´s Year':'First_Policy','Brithday Year':'Birthday','Educational Degree':'Education','Gross Monthly Salary':'Salary','Geographic Living Area':'Area','Has Children (Y=1)':'Children','Customer Monetary Value':'CMV','Claims Rate':'Claims','Premiums in LOB: Motor':'Motor','Premiums in LOB: Household':'Household','Premiums in LOB: Health':'Health','Premiums in LOB:  Life':'Life','Premiums in LOB: Work Compensations':'Work_Compensation'})
df
# Out:
#           ID  First_Policy  Birthday        Education  Salary  Area  Children  \
# 0          1        1985.0    1982.0  2 - High School  2177.0   1.0       1.0
# 1          2        1981.0    1995.0  2 - High School   677.0   4.0       1.0
# 2          3        1991.0    1970.0        1 - Basic  2277.0   3.0       0.0
# 3          4        1990.0    1981.0      3 - BSc/MSc  1099.0   4.0       1.0
# 4          5        1986.0    1973.0      3 - BSc/MSc  1763.0   4.0       1.0
# 5          6        1986.0    1956.0  2 - High School  2566.0   4.0       1.0
# 6          7        1979.0    1943.0  2 - High School  4103.0   4.0       0.0
# 7          8        1988.0    1974.0  2 - High School  1743.0   4.0       1.0
# 8          9        1981.0    1978.0      3 - BSc/MSc  1862.0   1.0       1.0
# 9         10        1976.0    1948.0      3 - BSc/MSc  3842.0   1.0       0.0
# 10        11        1990.0    1945.0      3 - BSc/MSc  3995.0   4.0       0.0
# ...

# %% [markdown]
# ## adding variables

# %%
df['Premiums_Sum'] = df['Motor'] +  df['Household'] + df['Health'] + df['Life'] + df['Work_Compensation']

# %%
df['Age'] = 2016 - df['Birthday']
df['Age_as_Client'] = 2016 - df['First_Policy']

# %%
df['Anual_Salary'] = df['Salary'] * 12

# %%
df.head()
# Out:
#    ID  First_Policy  Birthday        Education  Salary  Area  Children  \
# 0   1        1985.0    1982.0  2 - High School  2177.0   1.0       1.0
# 1   2        1981.0    1995.0  2 - High School   677.0   4.0       1.0
# 2   3        1991.0    1970.0        1 - Basic  2277.0   3.0       0.0
# 3   4        1990.0    1981.0      3 - BSc/MSc  1099.0   4.0       1.0
# 4   5        1986.0    1973.0      3 - BSc/MSc  1763.0   4.0       1.0
#
#       CMV  Claims   Motor  Household  Health    Life  Work_Compensation  \
# 0  380.97    0.39  375.85      79.45  146.36   47.01              16.89
# 1 -131.13    1.12   77.46     416.20  116.69  194.48             106.13
# 2  504.67    0.28  206.15     224.50  124.58   86.35              99.02
# 3  -16.99    0.99  182.48      43.35  311.17   35.34              28.34
# 4   35.23    0.90  338.62      47.80  182.59   18.78              41.45
#
#    Premiums_Sum   Age  Age_as_Client  Anual_Salary
# 0        665.56  34.0           31.0       26124.0
# ...

# %% [markdown]
# ## converting everything to numbers

# %%
df['Education'].unique()
# Out:
# array(['2 - High School', '1 - Basic', '3 - BSc/MSc', '4 - PhD'],
#       dtype=object)

# %%
df['Education'] = df['Education'].map({'1 - Basic':1,'2 - High School':2,'3 - BSc/MSc':3,'4 - PhD':4})

# %%
df['Education'].unique()
# Out:
# array([2, 1, 3, 4], dtype=int64)

# %% [markdown]
# ## outlier detection

# %%
df_outliers = df.copy(deep = True)
df_outliers = df_outliers.drop(df_outliers.index)
df_outliers
# Out:
# Empty DataFrame
# Columns: [ID, First_Policy, Birthday, Education, Salary, Area, Children, CMV, Claims, Motor, Household, Health, Life, Work_Compensation, Premiums_Sum, Age, Age_as_Client, Anual_Salary]
# Index: []

# %%
df = df.reset_index(drop = True)
df
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 0         1        1985.0    1982.0          2  2177.0   1.0       1.0
# 1         2        1981.0    1995.0          2   677.0   4.0       1.0
# 2         3        1991.0    1970.0          1  2277.0   3.0       0.0
# 3         4        1990.0    1981.0          3  1099.0   4.0       1.0
# 4         5        1986.0    1973.0          3  1763.0   4.0       1.0
# 5         6        1986.0    1956.0          2  2566.0   4.0       1.0
# 6         7        1979.0    1943.0          2  4103.0   4.0       0.0
# 7         8        1988.0    1974.0          2  1743.0   4.0       1.0
# 8         9        1981.0    1978.0          3  1862.0   1.0       1.0
# 9        10        1976.0    1948.0          3  3842.0   1.0       0.0
# 10       11        1990.0    1945.0          3  3995.0   4.0       0.0
# 11       12        1985.0    1958.0          3  2834.0   3.0       1.0
# ...

# %%
import seaborn as sns

# %%
sns.boxplot(x=df['First_Policy'])

# %%
df.loc[df['First_Policy']>10000]
# Out:
#         ID  First_Policy  Birthday  Education  Salary  Area  Children     CMV  \
# 9010  9295       53784.0    1948.0          3  3268.0   1.0       0.0  348.85
#
#       Claims  Motor  Household  Health   Life  Work_Compensation  \
# 9010    0.37  351.4       15.0  187.37  22.45              17.78
#
#       Premiums_Sum   Age  Age_as_Client  Anual_Salary
# 9010         594.0  68.0       -51768.0       39216.0

# %%
ind = df.loc[df['First_Policy']>10000].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['First_Policy'])

# %%
sns.boxplot(x=df['Birthday'])

# %%
df.loc[df['Birthday']<1800]
# Out:
#         ID  First_Policy  Birthday  Education  Salary  Area  Children     CMV  \
# 6972  7196        1993.0    1028.0          3  2830.0   4.0       0.0  146.02
#
#       Claims   Motor  Household  Health  Life  Work_Compensation  \
# 6972    0.77  428.97      192.8  108.91  1.89              23.67
#
#       Premiums_Sum    Age  Age_as_Client  Anual_Salary
# 6972        756.24  988.0           23.0       33960.0

# %%
ind = df.loc[df['Birthday']<1800].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['Birthday'])

# %%
sns.boxplot(x=df['Salary'])

# %%
df.loc[df['Salary']>10000]
# Out:
#         ID  First_Policy  Birthday  Education   Salary  Area  Children  \
# 5692  5883        1995.0    1956.0          2  55215.0   4.0       1.0
# 8012  8262        1981.0    1991.0          2  34490.0   4.0       0.0
#
#          CMV  Claims   Motor  Household  Health    Life  Work_Compensation  \
# 5692  122.25    0.79  281.83     147.25  130.58   84.46              66.68
# 8012  608.89    0.28   57.01     358.95  195.26  113.80             161.14
#
#       Premiums_Sum   Age  Age_as_Client  Anual_Salary
# 5692        710.80  60.0           21.0      662580.0
# 8012        886.16  25.0           35.0      413880.0

# %%
ind = df.loc[df['Salary']>10000].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['Salary'])

# %%
sns.boxplot(x=df['CMV'])

# %%
df.loc[df['CMV']<-25000]
# Out:
#         ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 167    172        1990.0    1989.0          3  1086.0   4.0       1.0
# 638    656        1974.0    1963.0          3  3279.0   3.0       1.0
# 658    676        1994.0    1937.0          2  4435.0   1.0       0.0
# 690    708        1991.0    1991.0          3  1634.0   1.0       1.0
# 890    918        1986.0    1952.0          2  3355.0   4.0       0.0
# 9350  9649        1990.0    1950.0          3  3574.0   3.0       0.0
#
#             CMV  Claims   Motor  Household  Health   Life  Work_Compensation  \
# 167  -165680.42   256.2  378.07      78.90  166.81   6.89              18.45
# 638   -64891.00    96.0  410.30     117.25   95.35  37.34              22.56
# 658   -52382.76    63.0  197.48     280.60  276.94  51.12              38.34
# 690   -28945.40    35.0  175.70     319.50  294.39  44.12              16.89
# 890   -26130.45    32.3  135.58     290.05  221.82  86.46             100.13
# ...

# %%
ind = df.loc[df['CMV']<-25000].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['CMV'])

# %%
df.loc[df['CMV']<-2500]
# Out:
#       ID  First_Policy  Birthday  Education  Salary  Area  Children       CMV  \
# 50    52        1982.0    1966.0          3  3234.0   4.0       1.0 -14714.08
# 110  113        1997.0    1979.0          4  2354.0   1.0       1.0  -8719.04
# 133  136        1997.0    1988.0          3  2176.0   4.0       1.0 -10198.91
# 734  759        1988.0    1992.0          3  1117.0   1.0       1.0 -10107.37
# 766  794        1980.0    1983.0          3  1370.0   3.0       1.0  -7851.17
# 919  952        1998.0    1976.0          3  1586.0   3.0       1.0  -2642.91
# 949  983        1989.0    1981.0          2  1771.0   3.0       1.0  -6115.85
#
#      Claims   Motor  Household  Health    Life  Work_Compensation  \
# 50    25.36  557.44      20.00   29.56    5.00              -9.00
# 110   15.65  518.32       4.45   55.90    3.89              10.89
# 133   14.80  297.61     162.80  143.36  136.47              -3.00
# 734   12.60  193.37     342.85  276.94    8.78              47.23
# ...

# %%
ind = df.loc[df['CMV']<-2500].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['CMV'])

# %%
df.loc[df['CMV']<-1000]
# Out:
#        ID  First_Policy  Birthday  Education  Salary  Area  Children      CMV  \
# 983  1026        1988.0    1939.0          3  4566.0   1.0       1.0 -2082.83
#
#      Claims   Motor  Household  Health   Life  Work_Compensation  \
# 983    4.36  370.07      14.45  189.59  14.78              23.56
#
#      Premiums_Sum   Age  Age_as_Client  Anual_Salary
# 983        612.45  77.0           28.0       54792.0

# %%
ind = df.loc[df['CMV']<-1000].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['CMV'])

# %%
df.loc[df['CMV']>1003]
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 247     258        1991.0    1995.0          3   380.0   1.0       0.0
# 255     266        1997.0    1990.0          3   881.0   1.0       1.0
# 290     302        1976.0    1991.0          1  1497.0   1.0       0.0
# 460     477        1977.0    1959.0          2  3067.0   2.0       1.0
# 580     601        1986.0    1991.0          1   789.0   1.0       1.0
# 607     629        1989.0    1994.0          1   967.0   2.0       1.0
# 628     650        1991.0    1973.0          1  1688.0   3.0       0.0
# 675     699        1975.0    1993.0          1   382.0   4.0       1.0
# 818     852        1974.0    1994.0          1   695.0   1.0       1.0
# 831     866        1979.0    2001.0          1   562.0   1.0       1.0
# 872     909        1981.0    1990.0          3  1917.0   3.0       1.0
# 1054   1098        1988.0    1990.0          1   854.0   4.0       0.0
# ...

# %%
ind = df.loc[df['CMV']>1003].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['CMV'])

# %%
sns.boxplot(x=df['Claims'])

# %%
sns.boxplot(x=df['Motor'])

# %%
df.loc[df['Motor']>2000]
# Out:
#         ID  First_Policy  Birthday  Education  Salary  Area  Children     CMV  \
# 4902  5129        1996.0    1943.0          1  3763.0   1.0       0.0  466.21
# 4981  5212        1981.0    1943.0          2  4135.0   3.0       0.0  130.14
# 7582  7905        1974.0    1959.0          3  2354.0   4.0       1.0  -46.89
#
#       Claims    Motor  Household   Health    Life  Work_Compensation  \
# 4902    0.90  4003.44      612.9   137.36  121.69              31.34
# 4981    0.99  8744.61      101.7  1767.00  155.14             130.58
# 7582    1.01  3106.62       30.0    59.01   12.89               9.00
#
#       Premiums_Sum   Age  Age_as_Client  Anual_Salary
# 4902       4906.73  73.0           20.0       45156.0
# 4981      10899.03  73.0           35.0       49620.0
# 7582       3217.52  57.0           42.0       28248.0

# %%
ind = df.loc[df['Motor']>2000].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['Motor'])

# %%
sns.boxplot(x=df['Household'])

# %%
df.loc[df['Household']>600]
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 16       17        1991.0    1989.0          2  2437.0   1.0       1.0
# 98      102        1981.0    1956.0          1  2694.0   3.0       1.0
# 105     109        1991.0    1995.0          1   764.0   4.0       1.0
# 123     128        1978.0    1952.0          2  3481.0   3.0       0.0
# 145     153        1981.0    1989.0          2  1753.0   4.0       0.0
# 148     156        1986.0    1992.0          3  1354.0   3.0       0.0
# 174     183        1995.0    1991.0          2   826.0   1.0       0.0
# 177     187        1993.0    1999.0          1  1247.0   2.0       1.0
# 192     203        1989.0    1960.0          3  2544.0   4.0       1.0
# 223     234        1995.0    1985.0          2  1650.0   1.0       1.0
# 240     251        1991.0    1987.0          2  1579.0   4.0       1.0
# 245     256        1976.0    1944.0          1  3842.0   1.0       0.0
# ...

# %%
ind = df.loc[df['Household']>600].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['Household'])

# %%
df.loc[df['Household']>500]
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 43       46        1991.0    1984.0          3  1937.0   3.0       1.0
# 64       68        1989.0    1984.0          2  1866.0   1.0       1.0
# 113     121        1989.0    1984.0          2  1444.0   1.0       1.0
# 153     167        1995.0    1951.0          1  3617.0   4.0       1.0
# 171     189        1977.0    1951.0          3  3035.0   3.0       1.0
# 174     192        1996.0    1994.0          1  1486.0   2.0       0.0
# 216     237        1987.0    1948.0          2  3573.0   4.0       0.0
# 218     239        1992.0    1972.0          2  1889.0   4.0       1.0
# 255     280        1998.0    1938.0          1  4386.0   1.0       0.0
# 259     284        1988.0    1997.0          1  1281.0   3.0       1.0
# 318     349        1975.0    1991.0          3  1628.0   3.0       1.0
# 335     367        1985.0    1995.0          2  1233.0   1.0       1.0
# ...

# %%
ind = df.loc[df['Household']>500].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['Household'])

# %%
df.loc[df['Household']>489]
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 564     647        1979.0    1996.0          1   595.0   3.0       1.0
# 956    1131        1989.0    1997.0          1  1224.0   4.0       1.0
# 1052   1240        1985.0    1993.0          3  1135.0   1.0       1.0
# 1234   1452        1987.0    1992.0          2  1389.0   2.0       0.0
# 1853   2162        1988.0    1946.0          2  4154.0   1.0       0.0
# 1867   2178        1996.0    1942.0          3  3914.0   1.0       0.0
# 1903   2219        1996.0    1990.0          2   758.0   2.0       0.0
# 1925   2250        1985.0    1938.0          1  3779.0   2.0       0.0
# 2450   2856        1984.0    1965.0          1  2479.0   3.0       1.0
# 3224   3770        1986.0    1989.0          1  1247.0   3.0       1.0
# 3443   4022        1986.0    1959.0          1  3464.0   4.0       0.0
# 3506   4093        1985.0    1987.0          2  2240.0   4.0       1.0
# ...

# %%
ind = df.loc[df['Household']>489].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['Household'])

# %%
sns.boxplot(x=df['Health'])

# %%
df.loc[df['Health']>400]
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 98      106        1986.0    1988.0          3  2019.0   4.0       1.0
# 453     525        1986.0    1939.0          3  4056.0   2.0       0.0
# 938    1113        1989.0    1991.0          2  1927.0   1.0       1.0
# 1278   1515        1978.0    1942.0          3  3450.0   4.0       0.0
# 1715   2010        1989.0    1981.0          3  1973.0   4.0       1.0
# 5663   6617        1987.0    1988.0          3  1436.0   4.0       1.0
# 8766  10264        1985.0    1995.0          2   911.0   3.0       0.0
#
#          CMV  Claims   Motor  Household  Health   Life  Work_Compensation  \
# 98     -2.65    0.97   89.24      82.25  408.41  19.56              40.34
# 453    16.91    0.93   64.68      13.35  440.86  28.56              30.23
# 938   102.24    0.81   72.46      98.90  432.97  28.34              34.45
# 1278  100.58    0.82  138.36     117.80  401.63  12.78              25.67
# ...

# %%
ind = df.loc[df['Health']>400].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['Health'])

# %%
df.loc[df['Health']>389]
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 4240   4968        1981.0    1991.0          3  1135.0   4.0       1.0
# 4417   5184        1985.0    1985.0          2   826.0   4.0       1.0
# 5534   6468        1984.0    1950.0          2  4095.0   1.0       0.0
# 5939   6962        1978.0    1995.0          2  1290.0   3.0       1.0
# 8564  10043        1983.0    1943.0          3  4260.0   3.0       0.0
#
#          CMV  Claims   Motor  Household  Health   Life  Work_Compensation  \
# 4240  130.69    0.79  108.13     187.25  389.74  45.12              13.56
# 4417  -63.34    1.05  100.24     156.70  398.41  38.34               6.67
# 5534  259.72    0.66   76.46     285.05  393.74  12.89              63.90
# 5939   60.24    0.90   66.57     342.85  394.52  15.78              34.45
# 8564 -139.78    1.21  110.02     -25.55  390.74  10.78              63.68
#
#       Premiums_Sum   Age  Age_as_Client  Anual_Salary
# ...

# %%
ind = df.loc[df['Health']>389].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['Health'])

# %%
sns.boxplot(x=df['Life'])

# %%
df.loc[df['Life']>100]
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 1         2        1981.0    1995.0          2   677.0   4.0       1.0
# 13       14        1983.0    2000.0          1  1043.0   3.0       1.0
# 33       36        1990.0    1966.0          2  2420.0   3.0       0.0
# 38       41        1994.0    1995.0          2  1177.0   4.0       1.0
# 39       42        1988.0    1955.0          3  3256.0   1.0       1.0
# 42       45        1985.0    1990.0          3  1065.0   1.0       1.0
# 92       99        1988.0    1950.0          1  3870.0   1.0       1.0
# 124     138        1994.0    1953.0          2  3799.0   4.0       0.0
# 132     148        1979.0    1954.0          2  2951.0   3.0       1.0
# 202     229        1997.0    1987.0          3  1109.0   4.0       0.0
# 207     235        1991.0    1996.0          1  1980.0   2.0       1.0
# 216     246        1984.0    1993.0          1   566.0   3.0       1.0
# ...

# %%
ind = df.loc[df['Life']>100].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['Life'])

# %%
df.loc[df['Life']>89]
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 105     124        1991.0    1959.0          1  2957.0   1.0       1.0
# 109     129        1982.0    1946.0          3  3971.0   1.0       0.0
# 141     169        1977.0    1997.0          2   927.0   4.0       1.0
# 171     207        1978.0    1952.0          2  2900.0   1.0       0.0
# 225     273        1980.0    1981.0          2  2048.0   1.0       1.0
# 360     440        1992.0    1946.0          1  3827.0   4.0       0.0
# 433     541        1995.0    1994.0          2  1657.0   1.0       1.0
# 446     555        1990.0    1993.0          3  1403.0   3.0       1.0
# 454     565        1982.0    1995.0          2   805.0   1.0       0.0
# 458     570        1979.0    1989.0          2  1078.0   4.0       1.0
# 517     639        1985.0    1986.0          2  1345.0   1.0       1.0
# 540     668        1997.0    1958.0          2  3386.0   4.0       1.0
# ...

# %%
ind = df.loc[df['Life']>89].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['Life'])

# %%
sns.boxplot(x=df['Work_Compensation'])

# %%
df.loc[df['Work_Compensation']>100]
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 85       98        1996.0    1938.0          2  3924.0   4.0       0.0
# 88      103        1981.0    1980.0          2  2071.0   4.0       1.0
# 92      108        1989.0    1958.0          2  3673.0   3.0       1.0
# 123     150        1989.0    1994.0          1   984.0   4.0       1.0
# 125     152        1977.0    1984.0          2  1146.0   3.0       1.0
# 140     171        1984.0    1941.0          1  3916.0   4.0       0.0
# 148     180        1984.0    1982.0          2  1739.0   3.0       0.0
# 154     190        1986.0    1954.0          3  3057.0   2.0       1.0
# 194     238        1978.0    1964.0          2  2924.0   4.0       1.0
# 233     288        1988.0    1975.0          2  2193.0   3.0       1.0
# 243     304        1977.0    1985.0          3  1687.0   2.0       1.0
# 305     378        1989.0    1990.0          1  1356.0   3.0       1.0
# ...

# %%
ind = df.loc[df['Work_Compensation']>100].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['Work_Compensation'])

# %%
df.loc[df['Work_Compensation']>80]
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 1         3        1991.0    1970.0          1  2277.0   3.0       0.0
# 31       37        1982.0    1972.0          2  2401.0   4.0       1.0
# 92      112        1991.0    1950.0          3  3507.0   3.0       0.0
# 162     210        1985.0    1984.0          2   873.0   1.0       1.0
# 183     232        1975.0    1944.0          2  3851.0   3.0       0.0
# 216     278        1991.0    1948.0          1  2937.0   3.0       0.0
# 251     324        1980.0    1990.0          2  1081.0   1.0       1.0
# 280     362        1988.0    1944.0          3  3806.0   4.0       0.0
# 311     404        1994.0    1954.0          2  3757.0   3.0       0.0
# 339     439        1987.0    1974.0          1  1475.0   1.0       1.0
# 343     445        1981.0    1988.0          2   865.0   3.0       1.0
# 349     452        1994.0    1943.0          2  4132.0   4.0       0.0
# ...

# %%
ind = df.loc[df['Work_Compensation']>80].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['Work_Compensation'])

# %%
df.loc[df['Work_Compensation']>79]
# Out:
#         ID  First_Policy  Birthday  Education  Salary  Area  Children     CMV  \
# 56      71        1994.0    1952.0          2  3382.0   2.0       0.0   83.90
# 417    576        1986.0    1946.0          3  3654.0   1.0       0.0  424.53
# 499    684        1987.0    1980.0          2  2050.0   3.0       1.0    2.57
# 1550  2176        1989.0    1981.0          2  1561.0   2.0       1.0  415.75
# 1857  2621        1996.0    1987.0          2  2177.0   1.0       1.0    8.68
# 2077  2921        1992.0    1980.0          3  2281.0   4.0       1.0  108.47
# 2226  3126        1994.0    1982.0          2  1388.0   1.0       1.0  109.58
# 2719  3832        1992.0    1987.0          1  1212.0   1.0       1.0  159.59
# 3010  4230        1996.0    1965.0          3  2948.0   1.0       0.0   36.90
# 3123  4384        1992.0    1950.0          1  2935.0   3.0       1.0   87.02
# 3415  4799        1980.0    1939.0          2  4244.0   3.0       0.0  368.51
# ...

# %%
ind = df.loc[df['Work_Compensation']>79].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['Work_Compensation'])

# %%
sns.boxplot(x=df['Premiums_Sum'])

# %%
df.loc[df['Premiums_Sum']>936]
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 45       58        1992.0    1949.0          2  3538.0   4.0       0.0
# 61       77        1996.0    1949.0          3  4196.0   4.0       0.0
# 94      119        1978.0    1960.0          2  2181.0   3.0       1.0
# 275     366        1975.0    1945.0          2  3377.0   3.0       0.0
# 383     526        1977.0    1940.0          3  3936.0   4.0       0.0
# 391     538        1980.0    1939.0          3  3934.0   4.0       0.0
# 408     560        1977.0    1990.0          3  1077.0   3.0       1.0
# 485     669        1975.0    1962.0          2  2622.0   2.0       1.0
# 547     766        1984.0    1987.0          2  1674.0   3.0       1.0
# 558     785        1995.0    1943.0          2  3759.0   4.0       1.0
# 706     998        1991.0    1940.0          1  3872.0   4.0       0.0
# 714    1011        1982.0    1947.0          2  4869.0   4.0       0.0
# ...

# %%
ind = df.loc[df['Premiums_Sum']>936].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
sns.boxplot(x=df['Premiums_Sum'])

# %%
sns.boxplot(x=df['Age'])

# %%
sns.boxplot(x=df['Age_as_Client'])

# %%
sns.boxplot(x=df['Anual_Salary'])

# %%
df
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 0         1        1985.0    1982.0          2  2177.0   1.0       1.0
# 1         4        1990.0    1981.0          3  1099.0   4.0       1.0
# 2         5        1986.0    1973.0          3  1763.0   4.0       1.0
# 3         6        1986.0    1956.0          2  2566.0   4.0       1.0
# 4         7        1979.0    1943.0          2  4103.0   4.0       0.0
# 5         8        1988.0    1974.0          2  1743.0   4.0       1.0
# 6         9        1981.0    1978.0          3  1862.0   1.0       1.0
# 7        10        1976.0    1948.0          3  3842.0   1.0       0.0
# 8        11        1990.0    1945.0          3  3995.0   4.0       0.0
# 9        12        1985.0    1958.0          3  2834.0   3.0       1.0
# 10       13        1981.0    1949.0          3  3757.0   1.0       0.0
# 11       15        1983.0    1975.0          2  1981.0   1.0       1.0
# ...

# %% [markdown]
# ## non-sense values

# %%
df['First_Policy'].nlargest(1)
# Out:
# 18    1998.0
# Name: First_Policy, dtype: float64

# %%
df['First_Policy'].nsmallest(1)
# Out:
# 20    1974.0
# Name: First_Policy, dtype: float64

# %%
df['Birthday'].nlargest(1)
# Out:
# 1500    1998.0
# Name: Birthday, dtype: float64

# %%
df['Birthday'].nsmallest(1)
# Out:
# 245    1935.0
# Name: Birthday, dtype: float64

# %%
df['Education'].unique()
# Out:
# array([2, 3, 1, 4], dtype=int64)

# %%
df['Salary'].nsmallest(1)
# Out:
# 2811    333.0
# Name: Salary, dtype: float64

# %% [markdown]
# this is smaller than the minimum wage in 2016 but some people don't work full time or are unemployed and have other means of remuneration

# %%
df['Salary'].nlargest(1)
# Out:
# 5260    5021.0
# Name: Salary, dtype: float64

# %%
df['Area'].unique()
# Out:
# array([1., 4., 3., 2.])

# %%
df['Children'].unique()
# Out:
# array([1., 0.])

# %%
df.loc[df['First_Policy']<df['Birthday']]
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 14       19        1981.0    1982.0          1  1414.0   3.0       1.0
# 17       23        1976.0    1986.0          2  1495.0   1.0       1.0
# 35       47        1976.0    1986.0          3  1219.0   4.0       1.0
# 55       72        1985.0    1989.0          3  1159.0   4.0       1.0
# 78       96        1976.0    1986.0          3  2668.0   4.0       1.0
# 103     135        1976.0    1977.0          4  1810.0   2.0       1.0
# 108     143        1984.0    1986.0          4  1266.0   2.0       1.0
# 110     146        1983.0    1986.0          1  2554.0   1.0       1.0
# 121     162        1975.0    1977.0          3  2285.0   1.0       0.0
# 152     206        1976.0    1983.0          2  1968.0   3.0       1.0
# 164     220        1985.0    1993.0          2  1342.0   4.0       1.0
# 172     228        1981.0    1982.0          2  1607.0   4.0       1.0
# ...

# %%
ind = df.loc[df['First_Policy']<df['Birthday']].index
lines = df.iloc[ind,:]
df_outliers = df_outliers.append(lines)
df = df.drop(ind)

# %%
df = df.reset_index(drop = True)

# %%
df.loc[df['Premiums_Sum']>df['Anual_Salary']]
# Out:
# Empty DataFrame
# Columns: [ID, First_Policy, Birthday, Education, Salary, Area, Children, CMV, Claims, Motor, Household, Health, Life, Work_Compensation, Premiums_Sum, Age, Age_as_Client, Anual_Salary]
# Index: []

# %%
df
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 0         1        1985.0    1982.0          2  2177.0   1.0       1.0
# 1         4        1990.0    1981.0          3  1099.0   4.0       1.0
# 2         5        1986.0    1973.0          3  1763.0   4.0       1.0
# 3         6        1986.0    1956.0          2  2566.0   4.0       1.0
# 4         7        1979.0    1943.0          2  4103.0   4.0       0.0
# 5         8        1988.0    1974.0          2  1743.0   4.0       1.0
# 6         9        1981.0    1978.0          3  1862.0   1.0       1.0
# 7        10        1976.0    1948.0          3  3842.0   1.0       0.0
# 8        11        1990.0    1945.0          3  3995.0   4.0       0.0
# 9        12        1985.0    1958.0          3  2834.0   3.0       1.0
# 10       13        1981.0    1949.0          3  3757.0   1.0       0.0
# 11       15        1983.0    1975.0          2  1981.0   1.0       1.0
# ...

# %% [markdown]
# ## discretization

# %%
df['Discr_Age'] = df['Age']
df['Discr_Age'] = df['Discr_Age'].map(lambda x: (x//10)*10)

# %%
df
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 0         1        1985.0    1982.0          2  2177.0   1.0       1.0
# 1         4        1990.0    1981.0          3  1099.0   4.0       1.0
# 2         5        1986.0    1973.0          3  1763.0   4.0       1.0
# 3         6        1986.0    1956.0          2  2566.0   4.0       1.0
# 4         7        1979.0    1943.0          2  4103.0   4.0       0.0
# 5         8        1988.0    1974.0          2  1743.0   4.0       1.0
# 6         9        1981.0    1978.0          3  1862.0   1.0       1.0
# 7        10        1976.0    1948.0          3  3842.0   1.0       0.0
# 8        11        1990.0    1945.0          3  3995.0   4.0       0.0
# 9        12        1985.0    1958.0          3  2834.0   3.0       1.0
# 10       13        1981.0    1949.0          3  3757.0   1.0       0.0
# 11       15        1983.0    1975.0          2  1981.0   1.0       1.0
# ...

# %%
df['Discr_Client_Age'] = df['Age_as_Client']
df['Discr_Client_Age'] = df['Discr_Client_Age'].map(lambda x: (x//10)*10)

# %%
df
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 0         1        1985.0    1982.0          2  2177.0   1.0       1.0
# 1         4        1990.0    1981.0          3  1099.0   4.0       1.0
# 2         5        1986.0    1973.0          3  1763.0   4.0       1.0
# 3         6        1986.0    1956.0          2  2566.0   4.0       1.0
# 4         7        1979.0    1943.0          2  4103.0   4.0       0.0
# 5         8        1988.0    1974.0          2  1743.0   4.0       1.0
# 6         9        1981.0    1978.0          3  1862.0   1.0       1.0
# 7        10        1976.0    1948.0          3  3842.0   1.0       0.0
# 8        11        1990.0    1945.0          3  3995.0   4.0       0.0
# 9        12        1985.0    1958.0          3  2834.0   3.0       1.0
# 10       13        1981.0    1949.0          3  3757.0   1.0       0.0
# 11       15        1983.0    1975.0          2  1981.0   1.0       1.0
# ...

# %%
df['Discr_Salary'] = df['Salary']
df['Discr_Salary'] = df['Discr_Salary'].map(lambda x: (x//500)*500)

# %%
df
# Out:
#          ID  First_Policy  Birthday  Education  Salary  Area  Children  \
# 0         1        1985.0    1982.0          2  2177.0   1.0       1.0
# 1         4        1990.0    1981.0          3  1099.0   4.0       1.0
# 2         5        1986.0    1973.0          3  1763.0   4.0       1.0
# 3         6        1986.0    1956.0          2  2566.0   4.0       1.0
# 4         7        1979.0    1943.0          2  4103.0   4.0       0.0
# 5         8        1988.0    1974.0          2  1743.0   4.0       1.0
# 6         9        1981.0    1978.0          3  1862.0   1.0       1.0
# 7        10        1976.0    1948.0          3  3842.0   1.0       0.0
# 8        11        1990.0    1945.0          3  3995.0   4.0       0.0
# 9        12        1985.0    1958.0          3  2834.0   3.0       1.0
# 10       13        1981.0    1949.0          3  3757.0   1.0       0.0
# 11       15        1983.0    1975.0          2  1981.0   1.0       1.0
# ...

# %% [markdown]
# ## pca

# %%
my_data = df[['Motor','Household','Health','Life','Work_Compensation']]

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_PCA_scaled = scaler.fit_transform(my_data)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components= my_data.shape[1])
principalComponents = pca.fit_transform(X_PCA_scaled)

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.60106743, 0.75373568, 0.87927427, 0.99772369, 1.        ])

# %%
pca = PCA(n_components= 3)
principalComponents = pca.fit_transform(X_PCA_scaled)

# %%
pca.components_
# Out:
# array([[-0.55768288,  0.38493602,  0.46385479,  0.40860223,  0.39836793],
#        [ 0.27450566,  0.49137139, -0.67077101,  0.32415379,  0.35803822],
#        [ 0.03606597, -0.74694896, -0.08435092,  0.25794147,  0.60590231]])

# %% [markdown]
# pca1: inversely correlated with motor and correlated with the rest (all mildly)
#
# pca2: inversely correlated with health and correlated with the rest (all mildly)
#
# pca3: inversely correlated with household and correlated with work_compensation
#
# no real conclusion

# %% [markdown]
# ## redundancy

# %%
df_corr = df[['First_Policy','Birthday','Education','Salary','Area','Children','CMV','Claims','Motor','Household','Health','Life','Work_Compensation']]
correlation = df_corr.corr()
sb.heatmap(correlation)

# %%
# correlation between birthday and salary
correlation.loc['Birthday','Salary']
# Out:
# -0.8928252301744717

# %% [markdown]
# we should drop salary from the analysis since birthday is an essential data point for premium calculation #BusinessInsightYo

# %%
# correlation between CMV and claims
correlation.loc['CMV','Claims']
# Out:
# -0.9806674311316281

# %% [markdown]
# we should drop the claims because keeping cmv provides a clearer break between customer and product data

# %%
# correlation between motor and health
correlation.loc['Motor','Health']
# Out:
# -0.9148975131204349

# %%
corrs1 = []
corrs2 = []

for premium in ['Motor','Household','Health','Life','Work_Compensation']:
    corrs1.append(correlation.loc['Motor',premium])
    corrs2.append(correlation.loc['Health',premium])
    
print(corrs1)
print(corrs2)

# we should probably eliminate motor since it's more correlated with the other product variables
# Out:
# [1.0, -0.5581507347339831, -0.9148975131204349, -0.6084782558177626, -0.578572469553066]
# [-0.9148975131204349, 0.33136925880373863, 1.0, 0.3653710222735296, 0.3592537785815981]

# %% [markdown]
# we can eliminate one variable from each pair of variables since they explain each other
#
# FIND EXPLANATIONS!!

# %%
df.columns
# Out:
# Index(['ID', 'First_Policy', 'Birthday', 'Education', 'Salary', 'Area',
#        'Children', 'CMV', 'Claims', 'Motor', 'Household', 'Health', 'Life',
#        'Work_Compensation', 'Premiums_Sum', 'Age', 'Age_as_Client',
#        'Anual_Salary', 'Discr_Age', 'Discr_Client_Age', 'Discr_Salary'],
#       dtype='object')

# %% [markdown]
# # Clustering Metrics
# Elbow Graph

# %%
var_cluster = df.loc[:,['Household','Health','Life','Work_Compensation']].reindex()
var_cluster
# Out:
#       Household  Health   Life  Work_Compensation
# 0         79.45  146.36  47.01              16.89
# 1         43.35  311.17  35.34              28.34
# 2         47.80  182.59  18.78              41.45
# 3         18.90  114.80   7.00               7.67
# 4        295.60  317.95  14.67              26.34
# 5        397.30  144.36  66.68              53.23
# 6         18.35  210.04   8.78               9.89
# 7        182.25  271.94  39.23              55.12
# 8        116.70  227.71  18.67              10.89
# 9        216.70  252.38  36.34              35.45
# 10       340.05  257.05  43.12              15.78
# 11       -70.00   72.79  10.89              16.89
# 12        93.90  247.49  -3.00              19.67
# 13       107.80   86.35   3.89              27.56
# 14         9.45  125.69  24.45              30.56
# 15        65.00  221.93   3.89              33.34
# 16       329.50  248.38  48.01              33.56
# 17       128.35  135.58  15.67               4.78
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
cluster_Norm = scaler.fit_transform(var_cluster)
cluster_Norm = pd.DataFrame(cluster_Norm, columns = var_cluster.columns)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3,
               random_state=0,
               n_init=5,
               max_iter=30).fit(cluster_Norm)

my_clusters = kmeans.cluster_centers_
scaler.inverse_transform(X = my_clusters)
my_clusters = pd.DataFrame(scaler.inverse_transform(X = my_clusters),
                          columns = var_cluster.columns)
my_clusters
# Out:
#     Household      Health       Life  Work_Compensation
# 0   45.464086   96.549476   9.563274           9.262072
# 1  114.289492  218.051735  22.044228          21.516378
# 2  223.771626  189.661270  46.828479          43.660859

# %%
L = []
for i in range(1,20):
    kmeans = KMeans(n_clusters=i,
                   random_state=0,
                   n_init=5,
                   max_iter=200).fit(cluster_Norm)
    L.append(kmeans.inertia_)
plt.plot(range(1,20),L)

# %% [markdown]
# Silhouette Coefficient

# %%
# Check clusters a bit further
my_clusters = pd.DataFrame(scaler.inverse_transform(X=my_clusters),
                          columns=var_cluster.columns)
from sklearn.metrics import silhouette_samples, silhouette_score
silhouette_avg = silhouette_score(cluster_Norm, kmeans.labels_)

n_clusters = 3

print("For n_clusters=", n_clusters,
     "The average silhouette_score is:", silhouette_avg)

# Compute the silhouette scores for each sample
sample_silhouette_values = silhouette_samples(cluster_Norm, kmeans.labels_)
cluster_labels = kmeans.labels_
cluster_labels
# Out:
# For n_clusters= 3 The average silhouette_score is: 0.18584206622755794
# array([ 6, 15, 11, ...,  8,  2,  2])

# %%
import matplotlib.cm as cm
y_lower = 100
fig = plt.figure()
ax = fig.add_subplot(111)

ax.set_ylim([0, cluster_Norm.shape[0] + (n_clusters + 1) * 10])

for i in range(n_clusters):
    ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]
    ith_cluster_silhouette_values.sort()
    
    size_cluster_i = ith_cluster_silhouette_values.shape[0]
    y_upper = y_lower + size_cluster_i
    
    color = cm.rainbow(float(i) / n_clusters)
    ax.fill_betweenx(np.arange(y_lower, y_upper),
                    0, ith_cluster_silhouette_values,
                    facecolor=color,
                    edgecolor=color,
                    alpha=0.7)
    
    ax.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
    
    y_lower = y_upper + 100
    
    ax.set_title("The silhouette plot for the various clusters.")
    ax.set_xlabel("The silhouette coefficient values")
    ax.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax.axvline(x=silhouette_avg, color="red", linestyle="--")
    
plt.show()

# %% [markdown]
# # Clustering
# ## Partition-based
# K-Means

# %%
n_clusters = 3
kmeans = KMeans(n_clusters=n_clusters,
               random_state=0,
               n_init=10,
               max_iter=2000).fit(cluster_Norm)
my_clusters = pd.DataFrame(kmeans.cluster_centers_)
my_clusters
# Out:
#           0         1         2         3
# 0 -0.609208 -0.828357 -0.631469 -0.627639
# 1  0.013101  0.774510 -0.049213 -0.019377
# 2  0.999419  0.402941  1.115271  1.071189

# %%
plt.scatter(cluster_Norm.iloc[:, 0].values, cluster_Norm.iloc[:, 1].values, c=kmeans.labels_, cmap='rainbow') #c=kmeans, cmap='viridis')
# add centroids
plt.scatter(my_clusters.iloc[:, 0].values, my_clusters.iloc[:, 1].values, c='black');

# %% [markdown]
# ## Hierarchical-based
# Dendrogram

# %%
import scipy
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.cluster import hierarchy
from pylab import rcParams
import sklearn
from sklearn.cluster import AgglomerativeClustering
import sklearn.metrics as sm

# %%
plt.figure(figsize=(10,5))
plt.style.use('seaborn-whitegrid')
# Scipy generate dendrograms
Z = linkage(cluster_Norm, method='ward')

# %%
dendrogram(Z,
          truncate_mode='lastp',
          p=10,
          orientation='top',
          leaf_rotation=45.,
          leaf_font_size=10.,
          show_contracted=True,
          show_leaf_counts=True, color_threshold=50, above_threshold_color='k')

plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Cluster Size')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# ## Density-based
# DBSCAN
# !!! WIP !!!

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics

db = DBSCAN(eps= 50,
            min_samples=10).fit(cluster_Norm)

labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

unique_clusters, counts_clusters = np.unique(db.labels_, return_counts = True)
print(np.asarray((unique_clusters, counts_clusters)))
# table results: -1 is noise, get two clusters
# biggest cluster: 8904, decrease radius/eps to 0.5 --> 4 clusters
# try even smaller radius: 0.25 --> even more noise: 4670 and a few clusters
from sklearn.decomposition import PCA
pca = PCA(n_components=2).fit(cluster_Norm)
pca_2d = pca.transform(cluster_Norm)
for i in range(0, pca_2d.shape[0]):
    if db.labels_[i] == 0:
        c1 = plt.scatter(pca_2d[i,0],pca_2d[i,1],c='r',marker='+')
    elif db.labels_[i] == 1:
        c2 = plt.scatter(pca_2d[i,0],pca_2d[i,1],c='g',marker='o')
    elif db.labels_[i] == 2:
        c4 = plt.scatter(pca_2d[i,0],pca_2d[i,1],c='k',marker='v')
    elif db.labels_[i] == 3:
        c5 = plt.scatter(pca_2d[i,0],pca_2d[i,1],c='y',marker='s')
    elif db.labels_[i] == 4:
        c6 = plt.scatter(pca_2d[i,0],pca_2d[i,1],c='m',marker='p')
    elif db.labels_[i] == 5:
        c7 = plt.scatter(pca_2d[i,0],pca_2d[i,1],c='c',marker='H')
    elif db.labels_[i] == -1:
        c3 = plt.scatter(pca_2d[i,0],pca_2d[i,1],c='b',marker='*')

plt.legend([c1, c3], ['Cluster 1', 'Cluster 2','Noise'])
plt.title('DBSCAN finds 2 clusters and noise')
plt.show()

#this is not good for continuous values, that´s our project case.
# Out:
# [[   0]
#  [6388]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-155-cb51c24c9cf5> in <module>
#      34         c3 = plt.scatter(pca_2d[i,0],pca_2d[i,1],c='b',marker='*')
#      35
# ---> 36 plt.legend([c1, c3], ['Cluster 1', 'Cluster 2','Noise'])
#      37 plt.title('DBSCAN finds 2 clusters and noise')
#      38 plt.show()
#
# NameError: name 'c3' is not defined

# %% [markdown]
# 3D Plot

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3).fit(cluster_Norm)
pca_3d = pca.transform(cluster_Norm)
#Add my visuals
my_color=[]
my_marker=[]
#Load my visuals
for i in range(pca_3d.shape[0]):
    if labels[i] == 0:
        my_color.append('r')
        my_marker.append('+')
    elif labels[i] == 1:
        my_color.append('b')
        my_marker.append('o')
    elif labels[i] == 2:
        my_color.append('g')
        my_marker.append('*')
    elif labels[i] == -1:
        my_color.append('k')
        my_marker.append('<')
        
        
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for i in range(500):
#for i in range(pca_3d.shape[0]):
    ax.scatter(pca_3d[i,0], pca_3d[i,1], pca_3d[i,2], c=my_color[i], marker=my_marker[i])
    
ax.set_xlabel('PCA 1')
ax.set_ylabel('PCA 2')
ax.set_zlabel('PCA 3')

# %% [markdown]
# ## Model-based
# Self-Organizing Maps

# %%
from sompy.sompy import SOMFactory
from sompy.visualization.plot_tools import plot_hex_map
import logging

cluster_Norm = pd.DataFrame(cluster_Norm, columns = var_cluster.columns)

X = cluster_Norm.values

names = ['Health',
         'Household',
         'Motor',
         'Work Compensation']
sm = SOMFactory().build(data = X,
               mapsize=(10,10),
               normalization = 'var',
               initialization='pca',#'random', 'pca'
               component_names=names,
               lattice='hexa',#'rect','hexa'
               training ='batch' )#'seq','batch'

sm.train(n_job=4,
         verbose='info',
         train_rough_len=30,
         train_finetune_len=100)


final_clusters = pd.DataFrame(sm._data, columns = ['Health',
         'Household',
         'Motor',
         'Work Compensation'])

my_labels = pd.DataFrame(sm._bmu[0])
    
final_clusters = pd.concat([final_clusters,my_labels], axis = 1)

final_clusters.columns = ['Health',
         'Household',
         'Motor',
         'Work Compensation', 'Lables']

# %%
from sompy.visualization.mapview import View2DPacked
view2D  = View2DPacked(10,10,"", text_size=7)
view2D.show(sm, col_sz=5, what = 'codebook',)#which_dim="all", denormalize=True)
plt.show()

# %%
from sompy.visualization.mapview import View2D
view2D  = View2D(10,10,"", text_size=7)
view2D.show(sm, col_sz=5, what = 'codebook',)#which_dim="all", denormalize=True)
plt.show()

# %%
from sompy.visualization.bmuhits import BmuHitsView
vhts  = BmuHitsView(12,12,"Hits Map",text_size=7)
vhts.show(sm, anotate=True, onlyzeros=False, labelsize=10, cmap="autumn", logaritmic=False)

# %%
# K-Means Clustering
from sompy.visualization.hitmap import HitMapView
sm.cluster(3)
hits  = HitMapView(10,10,"Clustering",text_size=7)
a=hits.show(sm, labelsize=12)

# %% [markdown]
# Mean-Shift Clustering

# %%
from sklearn.cluster import MeanShift, estimate_bandwidth


to_MS = cluster_Norm
# The following bandwidth can be automatically detected using
my_bandwidth = estimate_bandwidth(to_MS,
                               quantile=0.2,
                               n_samples=1000)

ms = MeanShift(bandwidth=my_bandwidth,
               #bandwidth=0.15,
               bin_seeding=True)

ms.fit(to_MS)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)


#Values
scaler.inverse_transform(X=cluster_centers)

#Count
unique, counts = np.unique(labels, return_counts=True)

print(np.asarray((unique, counts)).T)

# lets check our are they distributed

from sklearn.decomposition import PCA
pca = PCA(n_components=2).fit(to_MS)
pca_2d = pca.transform(to_MS)
for i in range(0, pca_2d.shape[0]):
    if labels[i] == 0:
        c1 = plt.scatter(pca_2d[i,0],pca_2d[i,1],c='r',marker='+')
    elif labels[i] == 1:
        c2 = plt.scatter(pca_2d[i,0],pca_2d[i,1],c='g',marker='o')
    elif labels[i] == 2:
        c3 = plt.scatter(pca_2d[i,0],pca_2d[i,1],c='b',marker='*')

plt.legend([c1, c2, c3], ['Cluster 1', 'Cluster 2','Cluster 3 '])
plt.title('Mean Shift found 3 clusters')
plt.show()

# %% [markdown]
# older and better Mean shift

# %% [markdown]
# ![Unbenannt.PNG](attachment:Unbenannt.PNG)
