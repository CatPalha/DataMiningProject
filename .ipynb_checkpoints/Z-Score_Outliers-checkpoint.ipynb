# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Read the csv file into a data frame
df = pd.read_csv('A2Z_insurance.csv')

# %%
df.rename(columns={"Customer Identity":"customer_id","First Policy´s Year":"first_policy_year","Brithday Year":"birthday_year","Educational Degree":"educational_degree","Gross Monthly Salary":"gross_monthly_salary","Geographic Living Area":"geographic_living_area","Has Children (Y=1)":"has_children","Customer Monetary Value":"customer_monetary_value","Claims Rate":"claims_rate","Premiums in LOB: Motor":"premiums_LOB_motor","Premiums in LOB: Household":"premiums_LOB_household","Premiums in LOB: Health":"premiums_LOB_health","Premiums in LOB:  Life":"premiums_LOB_life","Premiums in LOB: Work Compensations":"premiums_LOB_work_compensations"}, inplace=True)

# %% [markdown]
# First problems:
#     - people: too young / too old
#     - customer monetary value: min negative

# %%
df.describe()
# Out:
#        customer_id  first_policy_year  birthday_year  gross_monthly_salary  \
# count  10296.00000       10266.000000   10279.000000          10260.000000
# mean    5148.50000        1991.062634    1968.007783           2506.667057
# std     2972.34352         511.267913      19.709476           1157.449634
# min        1.00000        1974.000000    1028.000000            333.000000
# 25%     2574.75000        1980.000000    1953.000000           1706.000000
# 50%     5148.50000        1986.000000    1968.000000           2501.500000
# 75%     7722.25000        1992.000000    1983.000000           3290.250000
# max    10296.00000       53784.000000    2001.000000          55215.000000
#
#        geographic_living_area  has_children  customer_monetary_value  \
# count            10295.000000  10275.000000             10296.000000
# mean                 2.709859      0.706764               177.892605
# std                  1.266291      0.455268              1945.811505
# min                  1.000000      0.000000           -165680.420000
# 25%                  1.000000      0.000000                -9.440000
# 50%                  3.000000      1.000000               186.870000
# 75%                  4.000000      1.000000               399.777500
# max                  4.000000      1.000000             11875.890000
#
#         claims_rate  premiums_LOB_motor  premiums_LOB_household  \
# count  10296.000000        10262.000000            10296.000000
# mean       0.742772          300.470252              210.431192
# std        2.916964          211.914997              352.595984
# min        0.000000           -4.110000              -75.000000
# 25%        0.390000          190.590000               49.450000
# 50%        0.720000          298.610000              132.800000
# 75%        0.980000          408.300000              290.050000
# max      256.200000        11604.420000            25048.800000
#
#        premiums_LOB_health  premiums_LOB_life  premiums_LOB_work_compensations
# count         10253.000000       10192.000000                     10210.000000
# mean            171.580833          41.855782                        41.277514
# std             296.405976          47.480632                        51.513572
# min              -2.110000          -7.000000                       -12.000000
# 25%             111.800000           9.890000                        10.670000
# 50%             162.810000          25.560000                        25.670000
# 75%             219.820000          57.790000                        56.790000
# max           28272.000000         398.300000                      1988.700000

# %%
print(df.gross_monthly_salary.sum())
print(df.customer_monetary_value.sum())
# Out:
# 25718404.0
# 1831582.26

# %%
df_premiums = df[['premiums_LOB_motor', 'premiums_LOB_household', 'premiums_LOB_health', 'premiums_LOB_life', 'premiums_LOB_work_compensations']]
df_premiums_sum = df_premiums.sum().sum()

# %%
claim_rate = df['claims_rate'].sum().sum()
claim_rate
# Out:
# 7647.58

# %%
print(claim_rate * df_premiums_sum)
# Out:
# 60089185871.21386

# %%
print(df["first_policy_year"].mean())
df_fpolicy_mean = round(df["first_policy_year"].mean())
print(df_fpolicy_mean)
print(df['first_policy_year'].isnull().sum())
df_fpolicy = df['first_policy_year'].fillna(df_fpolicy_mean)
df_fpolicy.to_frame()
# check if there are nulls left
df_fpolicy.isnull().sum()
# Out:
# 1991.0626339372686
# 1991
# 30
# 0

# %%
df_birth_mean = round(df["birthday_year"].mean())
df['birthday_year'] = df['birthday_year'].fillna(df_birth_mean)
df_fpolicy_mean = round(df["first_policy_year"].mean())
df['first_policy_year'] = df['first_policy_year'].fillna(df_fpolicy_mean)
df['premiums_LOB_motor']= df['premiums_LOB_motor'].fillna(0)
df['premiums_LOB_health'] = df['premiums_LOB_health'].fillna(0)
df['premiums_LOB_life'] = df['premiums_LOB_life'].fillna(0)
df["premiums_LOB_work_compensations"] = df["premiums_LOB_work_compensations"].fillna(0)
#Replacing the NaN values of Has Children column based on their birthday date
df.loc[296, 'has_children'] = '1.0'
df.loc[619, 'has_children'] = '0.0'
df.loc[772, 'has_children'] = '1.0'
df.loc[2227, 'has_children'] = '1.0'
df.loc[2362, 'has_children'] = '1.0'
df.loc[2671, 'has_children'] = '1.0'
df.loc[2703, 'has_children'] = '1.0'
df.loc[2926, 'has_children'] = '1.0'
df.loc[3177, 'has_children'] = '1.0'
df.loc[3280, 'has_children'] = '1.0'
df.loc[3684, 'has_children'] = '1.0'
df.loc[4728, 'has_children'] = '1.0'
df.loc[5437, 'has_children'] = '1.0'
df.loc[6471, 'has_children'] = '1.0'
df.loc[6863, 'has_children'] = '0.0'
df.loc[7474, 'has_children'] = '1.0'
df.loc[8018, 'has_children'] = '1.0'
df.loc[8374, 'has_children'] = '0.0'
df.loc[8419, 'has_children'] = '1.0'
df.loc[9324, 'has_children'] = '1.0'
df.loc[10010, 'has_children'] = '1.0'

# %%
df.isnull().sum()
# Out:
# customer_id                         0
# first_policy_year                   0
# birthday_year                       0
# educational_degree                 17
# gross_monthly_salary               36
# geographic_living_area              1
# has_children                        0
# customer_monetary_value             0
# claims_rate                         0
# premiums_LOB_motor                  0
# premiums_LOB_household              0
# premiums_LOB_health                 0
# premiums_LOB_life                   0
# premiums_LOB_work_compensations     0
# dtype: int64

# %%
#for col in df:
col = "birthday_year", "gross_monthly_salary", "geographic_living_area", "customer_monetary_value", "claims_rate", "premiums_LOB_motor", "premiums_LOB_household", "premiums_LOB_health", "premiums_LOB_life", "premiums_LOB_work_compensations" 
for col in col:
#col = "premiums_LOB_motor"
    sns.boxplot(data=df[col],
            orient="h", whis=3.5)
    plt.ylabel(col)
    plt.show()

# %%
sns.set_style("darkgrid", {'figure.facecolor':'green',
                         'axes.axisbelow':False,
                         'axes.facecolor':'#ee1289'})
sns.set()
col = "customer_monetary_value", "claims_rate", "premiums_LOB_motor", "premiums_LOB_household", "premiums_LOB_health", "premiums_LOB_life", "premiums_LOB_work_compensations" 
for col in col:
    sns.distplot(df.loc[:,col],
                kde=False,
               hist=True,
               color = 'g').set_title('Insurance DB')
    plt.show()

# %%
# Detecting outliers with the z-score method
def col_outlier(df, threshold=3.0):
    #path_timeseries = pathlib.Path('/home/mle5fe/projects/project_zero_bup/py_project_zero_bup/src/py_project_zero_bup/mle5fe/DQcheck/images_zscore').mkdir(parents=True, exist_ok=True) 
    #path_image = {}
    outlier_counts = {}
    lower_limits = {}
    upper_limits = {}
    for i, col in enumerate(df._get_numeric_data()):
        y = df[col]
        mean_col = np.mean(y)
        std_col = np.std(y) 
        z_score = (y - mean_col)/std_col 
        is_outlier = np.abs(z_score) > threshold
        outlier_counts = np.sum(is_outlier)
        lower_limits = mean_col - std_col*threshold
        upper_limits = mean_col + std_col*threshold
        fig, axes = plt.subplots(figsize=(10, 5))
        hist_large = df[col].hist(bins=15)
        hist_large.set_title(col)
        plt.axvline(lower_limits, color='r', linestyle='dashed', linewidth=2)
        plt.axvline(upper_limits, color='r', linestyle='dashed', linewidth=2)
        #path = 'images_zscore/' + col + '.png'
        #plt.savefig(path)
        #path_image[col] = path
    return hist_large

col_outlier(df)

# %% [markdown]
# Distplots

# %%
sns.set_style("ticks")
# 'customer_id','first_policy_year', 'birthday_year', 'educational_degree', 'gross_monthly_salary', 'geographic_living_area', 'customer_monetary_value', 'claims_rate', 
sns.pairplot(df[['premiums_LOB_motor', 'premiums_LOB_household', 'premiums_LOB_health', 'premiums_LOB_life', 'premiums_LOB_work_compensations']],
            diag_kind='hist',
            kind='scatter',
            palette='husl',
            plot_kws={'alpha':0.6,
                     's':0.6,
                     'edgecolor':'k'},
            height=2)
plt.show()

# %% [markdown]
# Optimum number of clusters

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    km = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    km.fit(df)
    wcss.append(km.inertia_)
plt.plot(range(11,1),wcss)
plt.title('Elbow Method')
plt.xlabel("Number of clusters")
plt.ylabel("wcss")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-b5f8a2b0d357> in <module>
#       3 for i in range(1,11):
#       4     km = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
# ----> 5     km.fit(float(df))
#       6     wcss.append(km.inertia_)
#       7 plt.plot(range(11,1),wcss)
#
# TypeError: float() argument must be a string or a number, not 'DataFrame'

# %% [markdown]
# IQR Boxplot

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)

df_new = df_boxplot[~((df_boxplot < (Q1 - 1.5*IQR)) | (df_boxplot > (Q3 - 1.5*IQR))).any(axis=1)]
# the output is the IQR for each column
# Out:
# customer_id                        5147.5000
# first_policy_year                    12.0000
# birthday_year                        30.0000
# gross_monthly_salary               1584.2500
# geographic_living_area                3.0000
# customer_monetary_value             409.2175
# claims_rate                           0.5900
# premiums_LOB_motor                  217.2600
# premiums_LOB_household              240.6000
# premiums_LOB_health                 108.0475
# premiums_LOB_life                    47.1200
# premiums_LOB_work_compensations      46.0100
# dtype: float64

# %%
df_new.shape
# Out:
# (0, 14)
